# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nwaiwu Obianujunwa Caroline**
#
# __Data scientist__

# %% [markdown]
# _I am interested in data science because i want to be able to tell stories using data and create new models to solve problems._

# %% [markdown]
# ### It must be executed and must display an output.

# %%
"Hello world"
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# * This is a bullet
# 1. This a numberlist
# ![IMG_20180908_100929.jpg](attachment:2d7bad0b-df1e-4098-bf39-4c340c89f6b5.jpg)
